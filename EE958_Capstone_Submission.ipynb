# %% [markdown]
# <a href="https://colab.research.google.com/github/vartonk/EE958-Capstone/blob/main/EE958_Capstone_Submission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Submission File

# %%
import pandas as pd # Import the pandas library and assign it the alias 'pd'

# %%
df1 = pd.read_csv("answersB.csv") # Bengali
df2= pd.read_csv("answersH.csv")  # Hindi

# %%
df3 = pd.concat([df1, df2]) #Concat

# %%
df3
# Out:
#            ID                                        Translation
# 0      177039                                       বর্তমান ঘটনা
# 1      177040  ভগবানকে ধন্যবাদ কিন্তু শিবাজীকে তাঁর বাগদত্তা ...
# 2      177041  মাথা ব্যাথা অথবা ছাতি বা নাকে চুলকানি মাঝে এক ...
# 3      177042  তাকে বলে যে তাকে ভালবাসে যে সে তার মধুর বলে মন...
# 4      177043  অস্ট্রেলিয়া ব্রাজিল এর উল্লেখযোগ্য শতাংশ দুরে...
# ...       ...                                                ...
# 23080  563219  राम को एक ईमेल भेजकर पूछें और उसे कैसे मदद करत...
# 23081  563220  श्रीनगर के अंत में भारत सरकार के प्रोफेसर देवस...
# 23082  563221  प्रारंभिक रूप से ट्यूबों में पेलेट को असंयमिता...
# 23083  563222  दोनों हाथों की हड्‍डी के साथ दायें हाथ को सुचा...
# 23084  563223                        हमारा बिल भी अधिक ऊँचा था ।
#
# [42757 rows x 2 columns]

# %%
df3.to_csv('answersBH.csv', index = False)

# %%
filtered_data = pd.read_csv("answersBH.csv")

# %%
answer = "answer.csv"
with open(answer, "w") as f:
  f.writelines("ID\tTranslation\n")
  for i in range(filtered_data.shape[0]):
    f.writelines(f'{filtered_data["ID"][i]}\t"{filtered_data["Translation"][i]}"\n')

# %% [markdown]
# ### Make a zip file of answer.csv and save it as submission.zip and submit it

# %%
# !zip submission.zip answer.csv
# Out:
#   adding: answer.csv (deflated 78%)
